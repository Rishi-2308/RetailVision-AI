# %% [markdown]
# # 05 - LSTM training
# Train with `python behavior/train_lstm.py`; this notebook shows the saved curves and measured results.

# %%
import sys, os
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT)); os.chdir(ROOT)
import config, pandas as pd, numpy as np
import matplotlib.pyplot as plt

# %%
import json
m = json.load(open(config.REPORTS_DIR / 'lstm_metrics.json'))
print('epochs run:', m['epochs_run'], ' sequence length:', m['seq_len'])
for split in ('validation', 'test'):
    s = m['splits'][split]
    print(split, {k: round(s[k], 4) for k in ('accuracy', 'precision_macro', 'recall_macro', 'f1_macro')})

# %%
from IPython.display import Image, display
for f in ('lstm_loss_curve.png', 'lstm_accuracy_curve.png', 'confusion_matrix_lstm.png'):
    display(Image(str(config.REPORTS_DIR / f)))

# %%
print(open(config.REPORTS_DIR / 'model_comparison.md').read())  # run behavior/compare_models.py first
