# %% [markdown]
# # 03 - Feature extraction
# Pose landmarks (MediaPipe) + motion energy + derived movement features. Run `python behavior/feature_extraction.py` first.

# %%
import sys, os
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT)); os.chdir(ROOT)
import config, pandas as pd, numpy as np
import matplotlib.pyplot as plt

# %%
from behavior.feature_extraction import CHANNEL_NAMES
print(len(CHANNEL_NAMES), 'per-frame features:'); print(CHANNEL_NAMES)

# %%
d = np.load(config.PROCESSED_DIR / 'sequences.npz')
print({k: d[k].shape for k in d.files if k.startswith('X_')})

# %%
X = d['X_train']; y = d['y_train']
idx = CHANNEL_NAMES.index('wrist_speed')
for k, name in enumerate(config.CLASS_NAMES):
    plt.plot(X[y == k][:, :, idx].mean(0), label=name)
plt.legend(); plt.title('Mean wrist speed over the window, per class'); plt.show()

# %%
print('NaN values:', int(np.isnan(X).sum()))
f = pd.read_csv(config.PROCESSED_DIR / 'features.csv'); f.describe().T.head(15)
