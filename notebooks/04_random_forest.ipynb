# %% [markdown]
# # 04 - Random Forest baseline
# Train with `python behavior/train_random_forest.py`; this notebook only reads the saved, measured results.

# %%
import sys, os
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT)); os.chdir(ROOT)
import config, pandas as pd, numpy as np
import matplotlib.pyplot as plt

# %%
import json
m = json.load(open(config.REPORTS_DIR / 'random_forest_metrics.json'))
for split in ('validation', 'test'):
    s = m['splits'][split]
    print(split, {k: round(s[k], 4) for k in ('accuracy', 'precision_macro', 'recall_macro', 'f1_macro')})
print(m['splits']['test']['report'])

# %%
from IPython.display import Image
Image(str(config.REPORTS_DIR / 'confusion_matrix_rf.png'))

# %%
pd.read_csv(config.REPORTS_DIR / 'rf_top_features.csv', index_col=0)
